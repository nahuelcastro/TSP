# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %% [markdown]
# # Experimentos del TP2 - 1er cuatri 2021
# En esta carpeta de Jupyter vamos a poner lo relativo a realizar la experimentación computacional.
# - **Asegurarse de correr los experimentos en el notebook Experimentos antes de utilizar este notebook.**
# - En este archivo se lee el output de los experimentos y se muestra de manera gráfica esos resultados.

# %% [markdown]
# # Métodos
# Los métodos evaluados en este notebook son los siguientes:
#
# - **VMC** : vecino mas cercano
# - **AGM** : arbol generador minimo
# - **I** : incersion

# %% [markdown]
# # Experimentos
# Leemos el dataframe con todos los resultados.

# %%
df_resultados = pd.read_csv("resultados/resultado.csv");
df_resultados
# Out:
#       dataset   n   metodo      tiempo    costo  largolista  max_iter  \
# 0    berlin52  52  AGM-TS1     5.75046  10402.0          50        50
# 1    berlin52  52  AGM-TS1     5.45058  10402.0         100        50
# 2    berlin52  52  AGM-TS1     5.54075  10402.0         200        50
# 3    berlin52  52  AGM-TS1    15.77830   9896.0          50        50
# 4    berlin52  52  AGM-TS1    15.72100   9896.0         100        50
# ..        ...  ..      ...         ...      ...         ...       ...
# 862  berlin52  52    I-TS2   567.20800   8370.0         100      1000
# 863  berlin52  52    I-TS2   572.98400   8497.0         200      1000
# 864  berlin52  52    I-TS2  1016.90000   7866.0          50      1000
# 865  berlin52  52    I-TS2  1023.09000   7887.0         100      1000
# 866  berlin52  52    I-TS2  1022.08000   7811.0         200      1000
#
#      rang_iter  percentage
# 0           50           5
# 1           50           5
# 2           50           5
# 3           50          30
# 4           50          30
# ..         ...         ...
# 862        300          50
# 863        300          50
# 864        300         100
# 865        300         100
# 866        300         100
#
# [867 rows x 9 columns]

# %%
df_resultados["metodo"].unique()
# Out:
# array(['AGM-TS1', 'AGM-TS2', 'VMC-TS1', 'VMC-TS2', 'I-TS1', 'I-TS2',
#        'AGM', 'VMC', 'I'], dtype=object)

# %% [markdown]
# # Buscar parametros optimos tabu

# %% [markdown]
# ## GAP
# Creamos un dataframe para analizar el GAP relativo de cada metodo
#
#
# Gap relativo = (costo-optimo) /optimo

# %%
## gap = costo / optimo * 100 - 100 = gap
def gap(costo, optimo):
    return int(costo / optimo * 100 - 100)

dic_optimos = {'berlin52': 7542}

df_gap = df_resultados[(df_resultados["dataset"] == "berlin52") | (df_resultados["dataset"] == "ch150")].copy();
#df_gap.drop(df_gap.columns[[5,6,7,8]], axis=1, inplace=True)
list_gap = []
list_optimo = []
for index, row in df_gap.iterrows():
    costo = int(row['costo'])
    optimo = dic_optimos[row['dataset']]
    value_gap = (costo - optimo) / optimo 
    list_optimo.append(dic_optimos[row['dataset']])
    list_gap.append(value_gap)


df_gap['optimo'] = list_optimo
df_gap['gap'] = list_gap

# %%
df_gap.sort_values(by=['gap'],ascending=True).head(5)
# Out:
#       dataset   n   metodo    tiempo   costo  largolista  max_iter  rang_iter  \
# 698  berlin52  52  AGM-TS2   999.533  7702.0         200      1000         50
# 710  berlin52  52  AGM-TS2  1051.710  7747.0         200      1000        100
# 769  berlin52  52  VMC-TS2   976.039  7767.0         100      1000         50
# 721  berlin52  52  AGM-TS2   990.400  7772.0         100      1000        300
# 792  berlin52  52  VMC-TS2   967.889  7774.0          50      1000        300
#
#      percentage  optimo       gap
# 698         100    7542  0.021215
# 710         100    7542  0.027181
# 769         100    7542  0.029833
# 721         100    7542  0.030496
# 792         100    7542  0.030761

# %% [markdown]
# # VMC

# %% [markdown]
# ## Tabu search con memoria de ciclos

# %% [markdown]
# Buscamos los mejores parametros
#
# Con vmc: 200 	1000 	300 	100
#
# Gap :  	0.031291

# %%
df = df_gap[df_gap["metodo"] == "VMC-TS1"]
df.sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo    tiempo   costo  largolista  max_iter  rang_iter  \
# 758  berlin52  52  VMC-TS1  1007.340  7778.0         200      1000        300
# 734  berlin52  52  VMC-TS1   966.834  7820.0         200      1000         50
# 733  berlin52  52  VMC-TS1   931.254  7825.0         100      1000         50
#
#      percentage  optimo       gap
# 758         100    7542  0.031291
# 734         100    7542  0.036860
# 733         100    7542  0.037523

# %% [markdown]
# Como la diferencia en el gap entre ver 50 % de los vecinos y el 100% es menor a 0.05. Tomamos el primer metodo.

# %%
df = df_gap[df_gap["metodo"] == "VMC-TS1"]
print("Ver una porcion de vecinos:")
display(df[df["percentage"]<100].sort_values(by=['gap'],ascending=True).head(5))
print("Ver 100% de vecinos:")
df[df["percentage"]==100].sort_values(by=['gap'],ascending=True).head(1)
# Out:
# Ver una porcion de vecinos:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 295  berlin52  52  VMC-TS1  241.857  8180.0         100       500         50
# 729  berlin52  52  VMC-TS1  523.298  8298.0          50      1000         50
# 755  berlin52  52  VMC-TS1  532.349  8379.0         200      1000        300
# 296  berlin52  52  VMC-TS1  247.369  8380.0         200       500         50
# 308  berlin52  52  VMC-TS1  248.086  8381.0         200       500        100
#
#      percentage  optimo       gap
# 295          50    7542  0.084593
# 729          50    7542  0.100239
# 755          50    7542  0.110979
# 296          50    7542  0.111111
# 308          50    7542  0.111244
# Ver 100% de vecinos:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 758  berlin52  52  VMC-TS1  1007.34  7778.0         200      1000        300
#
#      percentage  optimo       gap
# 758         100    7542  0.031291

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "VMC-TS1"]

sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')

plt.xlabel('Iteraciones')

plt.show()

# %%
df = df_gap[df_gap["metodo"] == "VMC-TS1"]

sns.lineplot(data = df, x = "max_iter",y = "tiempo")
plt.show()

sns.lineplot(data = df, x = "percentage",y = "tiempo")
# Out:
# <AxesSubplot:xlabel='percentage', ylabel='tiempo'>

# %% [markdown]
# ## Tabu search con memoria de movimientos

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "VMC-TS2"]

sns.lineplot(data = df ,x = "max_iter",y = "gap",hue = "percentage" )

plt.legend(loc='lower left')

plt.xlabel('Iteraciones')

plt.show()

# %%
df = df_gap[df_gap["metodo"] == "VMC-TS2"]
df.sort_values(by=['gap'],ascending=True).head(1)
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 769  berlin52  52  VMC-TS2  976.039  7767.0         100      1000         50
#
#      percentage  optimo       gap
# 769         100    7542  0.029833

# %%
df = df_gap[df_gap["metodo"] == "VMC-TS2"]
display(df[df["percentage"]<100].sort_values(by=['gap'],ascending=True).head(3))
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 427  berlin52  52  VMC-TS2  248.129  8152.0         100       500        300
# 765  berlin52  52  VMC-TS2  530.861  8186.0          50      1000         50
# 779  berlin52  52  VMC-TS2  546.053  8348.0         200      1000        100
#
#      percentage  optimo       gap
# 427          50    7542  0.080880
# 765          50    7542  0.085388
# 779          50    7542  0.106868

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "VMC-TS2"]

sns.lineplot(data = df ,x = "largolista",y = "gap",hue = "percentage" )

plt.legend(loc='lower left')

plt.show()

# %% [markdown]
# ##  AGM

# %% [markdown]
# ## Tabu search con memoria de ciclos

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "AGM-TS1"]

sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')

plt.xlabel('Iteraciones')

plt.show()

# %%
df = df_gap[df_gap["metodo"] == "AGM-TS1"]

df[( df["percentage"]== 100 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo    tiempo   costo  largolista  max_iter  rang_iter  \
# 662  berlin52  52  AGM-TS1  1052.080  7796.0         200      1000         50
# 686  berlin52  52  AGM-TS1   994.117  7801.0         200      1000        300
# 674  berlin52  52  AGM-TS1   976.967  7807.0         200      1000        100
#
#      percentage  optimo       gap
# 662         100    7542  0.033678
# 686         100    7542  0.034341
# 674         100    7542  0.035137

# %%
df = df_gap[df_gap["metodo"] == "AGM-TS1"]

df[( df["percentage"]== 50 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 80   berlin52  52  AGM-TS1  252.205  8241.0         200       500         50
# 670  berlin52  52  AGM-TS1  542.842  8353.0         100      1000        100
# 681  berlin52  52  AGM-TS1  524.025  8374.0          50      1000        300
#
#      percentage  optimo       gap
# 80           50    7542  0.092681
# 670          50    7542  0.107531
# 681          50    7542  0.110316

# %% [markdown]
# ## Tabu search con memoria de movimientos

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "AGM-TS2"]

sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')

plt.xlabel('Iteraciones')

plt.show()

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "AGM-TS1"]

sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')

plt.xlabel('Iteraciones')

plt.show()

# %%
df = df_gap[df_gap["metodo"] == "AGM-TS2"]

df[( df["percentage"]== 50 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 694  berlin52  52  AGM-TS2  553.796  8199.0         100      1000         50
# 718  berlin52  52  AGM-TS2  532.236  8241.0         100      1000        300
# 706  berlin52  52  AGM-TS2  553.394  8290.0         100      1000        100
#
#      percentage  optimo       gap
# 694          50    7542  0.087112
# 718          50    7542  0.092681
# 706          50    7542  0.099178

# %%
df = df_gap[df_gap["metodo"] == "AGM-TS2"]

df[( df["percentage"]== 100 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo    tiempo   costo  largolista  max_iter  rang_iter  \
# 698  berlin52  52  AGM-TS2   999.533  7702.0         200      1000         50
# 710  berlin52  52  AGM-TS2  1051.710  7747.0         200      1000        100
# 721  berlin52  52  AGM-TS2   990.400  7772.0         100      1000        300
#
#      percentage  optimo       gap
# 698         100    7542  0.021215
# 710         100    7542  0.027181
# 721         100    7542  0.030496

# %%
df[( df["percentage"]== 100 )& (df["max_iter"] == 500)].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 214  berlin52  52  AGM-TS2  458.493  7831.0         100       500        300
# 201  berlin52  52  AGM-TS2  458.043  7869.0          50       500        100
# 189  berlin52  52  AGM-TS2  459.539  7893.0          50       500         50
#
#      percentage  optimo       gap
# 214         100    7542  0.038319
# 201         100    7542  0.043357
# 189         100    7542  0.046539

# %% [markdown]
# ## Insercion

# %% [markdown]
# ## Tabu search con memoria de ciclos

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "I-TS1"]

g = sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')
plt.xlabel('Iteraciones')
plt.show()

# %%
df = df_gap[df_gap["metodo"] == "I-TS1"]

df[( df["percentage"]== 100 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo    tiempo   costo  largolista  max_iter  rang_iter  \
# 828  berlin52  52  I-TS1   976.292  7783.0          50      1000        300
# 818  berlin52  52  I-TS1  1000.340  7803.0         200      1000        100
# 805  berlin52  52  I-TS1   980.872  7813.0         100      1000         50
#
#      percentage  optimo       gap
# 828         100    7542  0.031954
# 818         100    7542  0.034606
# 805         100    7542  0.035932

# %%
df = df_gap[df_gap["metodo"] == "I-TS1"]

df[( df["percentage"]== 50 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 510  berlin52  52  I-TS1  269.896  8265.0          50       500         50
# 802  berlin52  52  I-TS1  558.794  8399.0         100      1000         50
# 815  berlin52  52  I-TS1  561.208  8402.0         200      1000        100
#
#      percentage  optimo       gap
# 510          50    7542  0.095863
# 802          50    7542  0.113630
# 815          50    7542  0.114028

# %%
df = df_gap[df_gap["metodo"] == "I-TS1"]

df[( df["percentage"]== 100 )& (df["max_iter"] == 500)].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 526  berlin52  52  I-TS1  472.808  7841.0         100       500        100
# 538  berlin52  52  I-TS1  472.853  7875.0         100       500        300
# 514  berlin52  52  I-TS1  478.477  8013.0         100       500         50
#
#      percentage  optimo       gap
# 526         100    7542  0.039645
# 538         100    7542  0.044153
# 514         100    7542  0.062450

# %% [markdown]
# ## Tabu search con memoria de movimientos

# %%
sns.set_style("darkgrid")

df = df_gap[df_gap["metodo"] == "I-TS2"]

sns.lineplot(data = df, x = "max_iter",y = "gap",hue = "percentage")
plt.legend(loc='lower left')
plt.xlabel('Iteraciones')

plt.show()

# %%
df = df_gap[df_gap["metodo"] == "I-TS2"]

df[( df["percentage"]== 100 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 866  berlin52  52  I-TS2  1022.08  7811.0         200      1000        300
# 840  berlin52  52  I-TS2  1022.68  7821.0          50      1000         50
# 864  berlin52  52  I-TS2  1016.90  7866.0          50      1000        300
#
#      percentage  optimo       gap
# 866         100    7542  0.035667
# 840         100    7542  0.036993
# 864         100    7542  0.042959

# %%
df = df_gap[df_gap["metodo"] == "I-TS2"]

df[( df["percentage"]== 100 )& (df["max_iter"] == 500)].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 621  berlin52  52  I-TS2  487.416  7897.0          50       500         50
# 634  berlin52  52  I-TS2  490.039  7917.0         100       500        100
# 622  berlin52  52  I-TS2  490.432  7974.0         100       500         50
#
#      percentage  optimo       gap
# 621         100    7542  0.047070
# 634         100    7542  0.049722
# 622         100    7542  0.057279

# %%
df = df_gap[df_gap["metodo"] == "I-TS2"]

df[( df["percentage"]== 50 )].sort_values(by=['gap'],ascending=True).head(3)
# Out:
#       dataset   n metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 644  berlin52  52  I-TS2  287.909  8284.0         200       500        300
# 862  berlin52  52  I-TS2  567.208  8370.0         100      1000        300
# 849  berlin52  52  I-TS2  560.128  8403.0          50      1000        100
#
#      percentage  optimo       gap
# 644          50    7542  0.098382
# 862          50    7542  0.109785
# 849          50    7542  0.114161

# %%
# Out:
#       dataset   n   metodo   tiempo   costo  largolista  max_iter  rang_iter  \
# 662  berlin52  52  AGM-TS1  1052.08  7796.0         200      1000         50
#
#      percentage  optimo       gap
# 662         100    7542  0.033678

# %%
Metodos = ["AGM-TS1","AGM-TS2","VMC-TS1","VMC-TS2","I-TS1","I-TS2"]
dic_gap = {}
for m in Metodos :
    df = df = df_gap[df_gap["metodo"] == m]
    gap100 = df[( df["percentage"]== 100 )].sort_values(by=['gap'],ascending=True).head(1)["gap"].to_list()[0]    
    gap50 = df[( df["percentage"]== 50 )].sort_values(by=['gap'],ascending=True).head(1)["gap"].to_list()[0]  
    gapdif = gap50 -gap100
    dic_gap[m] = gapdif
dic_gap
# Out:
# {'AGM-TS1': 0.05900291699814372,
#  'AGM-TS2': 0.06589763988332008,
#  'VMC-TS1': 0.053301511535401754,
#  'VMC-TS2': 0.051047467515247955,
#  'I-TS1': 0.06390877751259613,
#  'I-TS2': 0.06271546009016175}

# %%
Metodos = ["AGM-TS1","AGM-TS2","VMC-TS1","VMC-TS2","I-TS1","I-TS2"]
dic_iter = {}
for m in Metodos :
    if dic_gap[m] < 0.06 :
        df = df = df_gap[df_gap["metodo"] == m]
        
        gap1000 = df[( df["percentage"]== 50 ) & ( df["max_iter"]== 1000 )  ].sort_values(by=['gap'],ascending=True).head(1)["gap"].to_list()[0]  
        gap500 = df[( df["percentage"]== 50 ) & ( df["max_iter"]== 500 )  ].sort_values(by=['gap'],ascending=True).head(1)["gap"].to_list()[0]  
        gapdif = gap500 -gap1000
        
        dic_iter[m] = gapdif
dic_iter
# Out:
# {'AGM-TS1': -0.014850172368072137,
#  'VMC-TS1': -0.015645717316361704,
#  'VMC-TS2': -0.004508088040307612}
